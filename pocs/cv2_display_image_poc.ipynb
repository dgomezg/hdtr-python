# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

img = cv2.imread("../samples/Toledo/sources/0001-enf.jpg")
plt.imshow(img, cmap="gray")
plt.xticks([]), plt.yticks([])
plt.show()
