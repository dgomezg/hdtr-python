# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

img = cv2.cvtColor(cv2.imread("../samples/Toledo/sources/0001-enf.jpg"), cv2.COLOR_BGR2RGB)

plt.imshow(img, cmap="gray")
plt.xticks([]), plt.yticks([])
plt.show()
